# %%
import IPython.display as ipd
import librosa
import os
import pandas as pd
import glob
import matplotlib.pyplot as plt

# %%
ipd.Audio('/home/jugs/Desktop/small_dataset/user10/SA1.WAV')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
data, sampling_rate = librosa.load('/home/jugs/Desktop/small_dataset/user10/SA1.WAV')

# %%
plt.figure(figsize=(12, 4))
librosa.display.waveplot(data, sr=sampling_rate)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-c30a336a2195> in <module>()
#       1 plt.figure(figsize=(12, 4))
# ----> 2 librosa.display.waveplot(data, sr=sampling_rate)
#
# AttributeError: module 'librosa' has no attribute 'display'
