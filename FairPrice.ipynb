# %%
import tensorflow as tf
import tfx
import tensorflow_data_validation as tfdv
import numpy as np
import os, sys
import json
# Out:
# /home/jugs/anaconda3/envs/myenv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/jugs/anaconda3/envs/myenv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/jugs/anaconda3/envs/myenv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
original_file = "/home/jugs/Documents/FairPrice/sample.csv"

fine_data_file = "/home/jugs/Documents/FairPrice/finedata.csv"
anamoly_data_file = "/home/jugs/Documents/FairPrice/anamolydata.csv"

# %%
def read_data(filename):
    with open(filename, "r") as f:
        data = f.readlines()
    return data

# %%
def datatype_conversion(line):   
    lsplit = line.split(",")
    lsplit[5] = float(line.split(",")[5].replace("\"","").replace("SGD",""))
    lsplit[16] = float(line.split(",")[5].replace("\"","").replace("SGD",""))
    line = (','.join(str(l) for l in lsplit))
    return line

# %%
def segregate_data(data):
    finedata = []
    finedata.append(data[0])
    anamolydata = []
    anamolydata.append(data[0])
    for line in data[1:]:
        linesplit = line.split(",")
        if len(linesplit) == 25:
            finedata.append(datatype_conversion(line))
        else:
            anamolydata.append(line)
    return finedata, anamolydata

# %%
def write_to_file(filename, data):
    with open(filename, "w+") as f:
        for line in data:
            f.write(line)
        f.close()

# %%
data = read_data(original_file)
finedata, anamolydata = segregate_data(data)
write_to_file(fine_data_file, finedata)
write_to_file(anamoly_data_file, anamolydata)

# %%
float(data[40].split(",")[5].replace("\"","").replace("SGD",""))
# Out:
# 3.45

# %%
finedata[40]
# Out:
# '"13147699","Tesco Handwash - Cherry Blossom","Tesco Handwash - Cherry Blossom","in stock","new",3.45,"https://www.fairprice.com.sg/searchterm/Tesco%20Handwash%20-%20Cherry%20Blossom","https://s3-ap-southeast-1.amazonaws.com/www8.fairprice.com.sg/fpol/media/images/product/XL/13147699_XL1.jpg","Tesco","adult","Health & Beauty","Buy 1 Tesco Handwash - Cherry Blossom @ $0.30 Off","Malaysia","B2B|","Tesco Non-Food","Tesco",3.45,"2019-10-01 00:00:00/2020-01-01 00:00:00","Tesco Handwash - Cherry Blossom","FairPrice: #1 Grocery Retailer","com.fairprice.mcomapp","FairPrice: #1 Grocery Retailer","1012365118","fairpriceonline://productdetail?productUrl=13147699","fairpriceonline://productdetail?productUrl=13147699"\n'

# %%
# fair_price_data_path = "/home/jugs/Documents/FairPrice/finefeed.csv"

# %%
fp_stats = tfdv.generate_statistics_from_csv(fine_data_file)
tfdv.visualize_statistics(fp_stats)
# Out:
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>

# %%
schema = tfdv.infer_schema(statistics=fp_stats)
tfdv.display_schema(schema=schema)
# Out:
#                                Type  Presence Valency              Domain
# Feature name
# 'ios_app_name'               STRING  required          'ios_app_name'
# 'ios_app_store_id'           INT     required          -
# 'sale_price_effective_date'  BYTES   optional  single  -
# 'rich_text_description'      BYTES   required          -
# 'android_url'                BYTES   required          -
# 'id'                         INT     required          -
# 'custom_label_1'             STRING  optional  single  'custom_label_1'
# 'brand'                      BYTES   optional  single  -
# 'custom_label_2'             BYTES   optional  single  -
# 'price'                      FLOAT   required          -
# 'age_group'                  STRING  required          'age_group'
# 'link'                       BYTES   required          -
# 'description'                BYTES   optional  single  -
# 'custom_label_4'             STRING  required          'custom_label_4'
# ...

# %%
column_names = [id, title, description, availability, condition, price, link, image_link, brand, age_group, product_type,	custom_label_0,	custom_label_1, custom_label_2,	custom_label_3,	custom_label_4,	sale_price, sale_price_effective_date, rich_text_description, android_app_name, android_package, ios_app_name,	ios_app_store_id, android_url, ios_url]
