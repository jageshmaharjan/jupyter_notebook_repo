# %%
import tensorflow as tf
import os, sys, json
import numpy as np
import tfx
import tensorflow_data_validation as tfdv
import sys, os

import pprint
import tempfile
# Out:
# /home/jugs/anaconda3/envs/myenv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/jugs/anaconda3/envs/myenv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/jugs/anaconda3/envs/myenv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
file_path = "/home/jugs/Documents/FairPrice/google_shopping_feed.xml"

# %%
train_stats = tfdv.generate_statistics_from_csv(file_path)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1021 16:22:00.534312 140484525168448 deprecation_wrapper.py:119] From /home/jugs/anaconda3/envs/myenv/lib/python3.6/site-packages/tensorflow_data_validation/utils/stats_gen_lib.py:165: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.
#
# W1021 16:22:00.541000 140484525168448 deprecation_wrapper.py:119] From /home/jugs/anaconda3/envs/myenv/lib/python3.6/site-packages/tensorflow_data_validation/utils/stats_gen_lib.py:321: The name tf.gfile.Glob is deprecated. Please use tf.io.gfile.glob instead.
#
# W1021 16:22:00.541920 140484525168448 deprecation_wrapper.py:119] From /home/jugs/anaconda3/envs/myenv/lib/python3.6/site-packages/tensorflow_data_validation/utils/stats_gen_lib.py:327: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
# ---------------------------------------------------------------------------
# ...

# %%
import xml.etree.ElementTree as et

# %%
xtree = et.parse(file_path)
xroot = xtree.getroot()
# Out:
# Traceback (most recent call last):
#
#   File "/home/jugs/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-6-d9fe7573bd4f>", line 1, in <module>
#     xtree = et.parse(file_path)
#
#   File "/home/jugs/anaconda3/envs/myenv/lib/python3.6/xml/etree/ElementTree.py", line 1196, in parse
#     tree.parse(source, parser)
#
#   File "/home/jugs/anaconda3/envs/myenv/lib/python3.6/xml/etree/ElementTree.py", line 597, in parse
#     self._root = parser._parse_whole(source)
#
#   File "<string>", line unknown
# ParseError: not well-formed (invalid token): line 2, column 441448
